# %%
# !ls
# Out:
# Untitled.ipynb                      test junk.ipynb
# current_errors_TopMcMr_20181006.png

# %%
cd ..
# Out:
# /Users/justingosses/Code/predictatops

# %%
# !ls
# Out:
# AAPG_Abstract_2019ACE.md README.md                docs
# AUTHORS.rst              README_0.rst             requirements_dev.txt
# CONTRIBUTING.rst         predictatops           results
# HISTORY.rst              predictatops.egg-info  setup.cfg
# LICENSE                  __pycache__              setup.py
# MANIFEST.in              data                     tests
# Makefile                 demo                     tox.ini

# %%
cd predictatops
# Out:
# /Users/justingosses/Code/predictatops/predictatops

# %%
# !ls
# Out:
# __init__.py                      features_runner.py
# __pycache__                      load.py
# balance.py                       load_runner.py
# balance_runner.py                main.py
# checkdata.py                     prediction.py
# checkdata_runner.py              prediction_runner.py
# cli.py                           split.py
# configurationplusfiles_runner.py trainclasses.py
# configurationsplusfiles.py       trainclasses_runner.py
# evaluate.py                      wellKNN_runner.py
# evaluate_runner.py

# %%
from predictatops import *

# %%
import checkdata_runner
# Out:
# /Users/justingosses/anaconda/envs/MannvilleDask2/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/justingosses/anaconda/envs/MannvilleDask2/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# head of picks df =      SitID  HorID      Pick  Quality
# 0  102496   1000       321        1
# 1  102496   2000                 -1
# 2  102496   3000                 -1
# 3  102496   4000                 -1
# 4  102496   5000       438        2
# must have curve list is:  ['ILD', 'NPHI', 'GR', 'DPHI', 'DEPT']
# set must_have_tops_list as:  [13000, 14000]
#  set self.top_name_col_in_picks_df as:  HorID
# config.siteID_col_in_picks_df =  SitID
# ...

# %%
import checkdata as checkdata

# %%
vars(checkdata)
# Out:
# {'__name__': 'checkdata',
#  '__doc__': None,
#  '__package__': '',
#  '__loader__': <_frozen_importlib_external.SourceFileLoader at 0x10d1e9320>,
#  '__spec__': ModuleSpec(name='checkdata', loader=<_frozen_importlib_external.SourceFileLoader object at 0x10d1e9320>, origin='/Users/justingosses/Code/predictatops/predictatops/checkdata.py'),
#  '__file__': '/Users/justingosses/Code/predictatops/predictatops/checkdata.py',
#  '__cached__': '/Users/justingosses/Code/predictatops/predictatops/__pycache__/checkdata.cpython-36.pyc',
#  '__builtins__': {'__name__': 'builtins',
#   '__doc__': "Built-in functions, exceptions, and other objects.\n\nNoteworthy: None is the `nil' object; Ellipsis represents `...' in slices.",
#   '__package__': '',
#   '__loader__': _frozen_importlib.BuiltinImporter,
#   '__spec__': ModuleSpec(name='builtins', loader=<class '_frozen_importlib.BuiltinImporter'>),
#   '__build_class__': <function __build_class__>,
#   '__import__': <function __import__>,
# ...

# %%
dir(checkdata)
# Out:
# ['CurvesAvailable',
#  'TopsAvailable',
#  'Well',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '__warningregistry__',
#  'configuration',
#  'findWellsWithCertainCurves',
#  'findWellsWithGivenTopsCurves',
#  'getCurvesListWithDifferentCurveName',
#  'glob',
#  'input_data',
#  'itertools',
#  'lasio',
#  'math',
#  'np',
#  'os',
#  'pd',
#  'pickle',
#  'plt',
#  'welly']

# %%
help(checkdata)
# Out:
# Help on module checkdata:
#
# NAME
#     checkdata
#
# CLASSES
#     builtins.object
#         CurvesAvailable
#         TopsAvailable
#
#     class CurvesAvailable(builtins.object)
#      |  Class that uses the configuration class and data_inpunt class objects and additional
#      |  user input to find out the number of wells of those available that have the tops we want.
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, input_data_obj, configuration_obj)
#      |      doc string goes here
#      |
#      |  countsOfCurves(self)
#      |      say what it does here
#      |
#      |  findAllCurvesInGivenWells(self)
#      |      say what it does here
#      |
#      |  findWellsWithCertainCurves(self)
#      |      Function takes in an object with keys that are well names and values that are all curves in that well and as the second argument an array of plentiful curves expected to be in every well
# ...

# %%
help(checkdata.CurvesAvailable)
# Out:
# Help on class CurvesAvailable in module checkdata:
#
# class CurvesAvailable(builtins.object)
#  |  Class that uses the configuration class and data_inpunt class objects and additional
#  |  user input to find out the number of wells of those available that have the tops we want.
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, input_data_obj, configuration_obj)
#  |      doc string goes here
#  |
#  |  countsOfCurves(self)
#  |      say what it does here
#  |
#  |  findAllCurvesInGivenWells(self)
#  |      say what it does here
#  |
#  |  findWellsWithCertainCurves(self)
#  |      Function takes in an object with keys that are well names and values that are all curves in that well and as the second argument an array of plentiful curves expected to be in every well
#  |      Function returns an array of wells that have the specified curves in the second argument.
#  |
#  |  getCurvesInMinNumberOfWells(self)
#  |      say what it does here
#  |
#  |  run_all(self)
# ...

# %%
import configurationplusfiles as config_1

# %%
help(config_1)
# Out:
# Help on module configurationsplusfiles:
#
# NAME
#     configurationsplusfiles
#
# CLASSES
#     builtins.object
#         configuration
#         input_data
#
#     class configuration(builtins.object)
#      |  class to keep configuration variables you might change between runs.
#      |  Types of information information stored in here would include paths and names of intermediate files,
#      |  so not initial input files which go in the input_data class, as well as which tops or curves were mandatory in well select.
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  get_must_have_curves(self, must_have_curves_in_list)
#      |      doc string goes here
#      |
#      |  get_must_have_tops__list(self)
#      |
#      |  get_picks_depth_col_in_picks_df(self)
#      |
#      |  get_quality_col_name_in_picks_df(self)
#      |
# ...

# %%
config_1.input_data.getattr()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-bcec8d8629c6> in <module>()
# ----> 1 config_1.input_data.getattr()
#
# AttributeError: type object 'input_data' has no attribute 'getattr'

# %%
vars(config_1.input_data).items()
# Out:
# dict_items([('__module__', 'configurationsplusfiles'), ('__doc__', 'doc string'), ('__init__', <function input_data.__init__ at 0xb1dc2d048>), ('load_wells_file', <function input_data.load_wells_file at 0xb1dc2d0d0>), ('load_gis_file', <function input_data.load_gis_file at 0xb1dc2d158>), ('set_wells_file_path', <function input_data.set_wells_file_path at 0xb1dc2d1e0>), ('set_gis_file_path', <function input_data.set_gis_file_path at 0xb1dc2d268>), ('__dict__', <attribute '__dict__' of 'input_data' objects>), ('__weakref__', <attribute '__weakref__' of 'input_data' objects>)])

# %%
config_1.input_data.__dict__
# Out:
# mappingproxy({'__module__': 'configurationsplusfiles',
#               '__doc__': 'doc string',
#               '__init__': <function configurationsplusfiles.input_data.__init__(self, picks_file_path, picks_delimiter_str, path_to_logs_str)>,
#               'load_wells_file': <function configurationsplusfiles.input_data.load_wells_file(self)>,
#               'load_gis_file': <function configurationsplusfiles.input_data.load_gis_file(self)>,
#               'set_wells_file_path': <function configurationsplusfiles.input_data.set_wells_file_path(self, wells_file_path_str, wells_file_delimiter)>,
#               'set_gis_file_path': <function configurationsplusfiles.input_data.set_gis_file_path(self, gis_file_path_str, gis_file_path_delimiter)>,
#               '__dict__': <attribute '__dict__' of 'input_data' objects>,
#               '__weakref__': <attribute '__weakref__' of 'input_data' objects>})

# %%
# !ls
# Out:
# __init__.py                      features_runner.py
# __pycache__                      load.py
# balance.py                       load_runner.py
# balance_runner.py                main.py
# checkdata.py                     prediction.py
# checkdata_runner.py              prediction_runner.py
# cli.py                           split.py
# configurationplusfiles_runner.py trainclasses.py
# configurationsplusfiles.py       trainclasses_runner.py
# evaluate.py                      wellKNN_runner.py
# evaluate_runner.py

# %%
#### This runs the configurationplusfiles_runner.py file and imports the resulting class objects: input_data_inst and config
from configurationplusfiles_runner import input_data_inst, config

# %%
vars(config)
# Out:
# {'csv_of_well_names_wTopsCuves__name': '',
#  'csv_of_well_names_wTopCurves__path': '.',
#  'must_have_curves_list': ['ILD', 'NPHI', 'GR', 'DPHI', 'DEPT'],
#  'must_have_tops__list': [13000, 14000],
#  'top_name_col_in_picks_df': 'HorID',
#  'siteID_col_in_picks_df': 'SitID',
#  'quality_col_name_in_picks_df': 'Quality',
#  'picks_depth_col_in_picks_df': 'Pick',
#  'quality_items_to_skip__list': [-1, 0],
#  'test': 'test0',
#  'threshold_returnCurvesThatArePresentInThisManyWells': 1916,
#  'results_path': '../results',
#  'availableData_path': 'availableData'}

# %%
#### These are the attributes of the class object that has been initiated & run with configuration variables.
vars(input_data_inst)
# Out:
# {'picks_file_path': '../data/SPE_006_originalData/OilSandsDB/PICKS.TXT',
#  'picks_delimiter_str': '\t',
#  'picks_df':         SitID  HorID      Pick  Quality
#  0      102496   1000       321        1
#  1      102496   2000                 -1
#  2      102496   3000                 -1
#  3      102496   4000                 -1
#  4      102496   5000       438        2
#  5      102496   6000                 -1
#  6      102496   7000       458        3
#  7      102496   9000       468        3
#  8      102496   9500       468        3
#  9      102496  10000     471.5        3
#  10     102496  11000       475        3
#  11     102496  12000       475        3
#  12     102496  13000       475        3
#  13     102496  14000       561        1
#  14     102497   1000       354        1
#  15     102497   2000                 -1
#  16     102497   3000                 -1
#  17     102497   4000                 -1
#  18     102497   5000       477        1
# ...

# %%
#### This is some of the documentation for that class input_data 
#### that is initiated with defaults and was run with additional configuration in the configurationplusfiles_runner 
help(input_data_inst)
# Out:
# Help on input_data in module configurationsplusfiles object:
#
# class input_data(builtins.object)
#  |  doc string
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, picks_file_path, picks_delimiter_str, path_to_logs_str)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  load_gis_file(self)
#  |      load wells file into pandas dataframe
#  |
#  |  load_wells_file(self)
#  |      load wells file into pandas dataframe
#  |
#  |  set_gis_file_path(self, gis_file_path_str, gis_file_path_delimiter)
#  |      set wells file path as attribute of object and returns wells data frame using load_well_file. Can be txt, tsv, or csv
#  |
#  |  set_wells_file_path(self, wells_file_path_str, wells_file_delimiter)
#  |      set wells file path as attribute of object and returns wells data frame using load_well_file. Can be txt, tsv, or csv
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
# ...
