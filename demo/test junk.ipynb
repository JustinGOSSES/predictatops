# %% [markdown]
# ## Scratch notebook for initial module development

# %%
from importlib import reload

# %%
import predictatops.main as strat

# %%
reload(predictatops)
# Out:
# <module 'predictatops' from '/Users/justingosses/Code/PackagePractice/predictatops/predictatops/__init__.py'>

# %%
dir(strat)
# Out:
# ['AvailableData',
#  'CreatesFeatures',
#  'EvaluateML',
#  'FindNeighbors',
#  'LoadNMerge',
#  'ML1',
#  'ML2',
#  'Map',
#  'Pipelines',
#  'PrintTest',
#  'Rebalance',
#  'SplitTrainTest',
#  'UmapHelper',
#  'Well',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'glob',
#  'itertools',
#  'lasio',
#  'np',
#  'pd',
#  'plt',
#  'printHello',
#  'welly']

# %%
cd PackagePractice/
# Out:
# /Users/justingosses/Code/PackagePractice

# %%
cd predictatops
# Out:
# /Users/justingosses/Code/PackagePractice/predictatops

# %%
# !ls
# Out:
# AUTHORS.rst             README.rst              setup.cfg
# CONTRIBUTING.rst        predictatops          setup.py
# HISTORY.rst             predictatops.egg-info test junk.ipynb
# LICENSE                 data                    tests
# MANIFEST.in             docs                    tox.ini
# Makefile                requirements_dev.txt

# %%
cd predictatops
# Out:
# /Users/justingosses/Code/PackagePractice/predictatops/predictatops

# %%
import main as strat

# %%
from importlib import reload

# %%
# import main as strat
# reload(strat)

# %%
main.printHello()
# Out:
# hello 4s

# %%
reload(predictatops)
# Out:
# <module 'predictatops' from '/Users/justingosses/Code/PackagePractice/predictatops/predictatops/__init__.py'>

# %%
# !ls
# Out:
# __init__.py __pycache__ cli.py      main.py

# %%
# %cd ..
# !ls
# Out:
# /Users/justingosses/Code/PackagePractice/predictatops
# AUTHORS.rst             README.rst              setup.cfg
# CONTRIBUTING.rst        predictatops          setup.py
# HISTORY.rst             predictatops.egg-info test junk.ipynb
# LICENSE                 data                    tests
# MANIFEST.in             docs                    tox.ini
# Makefile                requirements_dev.txt

# %%
# stratData = strat.AvailableData(".wellsTest",".")

# %%
# stratData

# %%
# stratData.path_to_wells

# %%
# stratData = strat.AvailableData("../wellsTest",".")

# %%
stratData = strat.AvailableData("./data/SPE_006_originalData/OilSandsDB/Logs","../data/SPE_006_originalData/OilSandsDB/PICKS.TXT")

# %%
stratData.path_to_wells
# Out:
# './data/SPE_006_originalData/OilSandsDB/Logs'

# %%
stratData.path_to_tops
# Out:
# '../data/SPE_006_originalData/OilSandsDB/PICKS.TXT'

# %%
stratData.load_picks_df()

# %%
picks_df = stratData.picks_df

# %%
picks_df
# Out:
#         SitID  HorID      Pick  Quality
# 0      102496   1000       321        1
# 1      102496   2000                 -1
# 2      102496   3000                 -1
# 3      102496   4000                 -1
# 4      102496   5000       438        2
# 5      102496   6000                 -1
# 6      102496   7000       458        3
# 7      102496   9000       468        3
# 8      102496   9500       468        3
# 9      102496  10000     471.5        3
# 10     102496  11000       475        3
# 11     102496  12000       475        3
# 12     102496  13000       475        3
# 13     102496  14000       561        1
# 14     102497   1000       354        1
# 15     102497   2000                 -1
# 16     102497   3000                 -1
# 17     102497   4000                 -1
# 18     102497   5000       477        1
# 19     102497   6000                 -1
# 20     102497   7000     499.5        3
# 21     102497   9000     502.5        3
# ...

# %%
# !ls
# Out:
# AUTHORS.rst             README.rst              setup.cfg
# CONTRIBUTING.rst        predictatops          setup.py
# HISTORY.rst             predictatops.egg-info test junk.ipynb
# LICENSE                 data                    tests
# MANIFEST.in             docs                    tox.ini
# Makefile                requirements_dev.txt

# %%
# stratData.

# %%
locations = stratData.load_locations_df("./data/well_lat_lng.csv")

# %%
locations

# %%
stratData.locations_df
# Out:
#        SitID      UWI (AGS)                  UWI  HorID      Pick  Quality  \
# 0     102496  0674010812000  00/12-08-067-01W4/0  13000       475        3
# 1     102497  0674020807000  00/07-08-067-02W4/0  13000       515        3
# 2     102498  0674021109000  00/09-11-067-02W4/0  13000       480        3
# 3     102500  0674022910000  00/10-29-067-02W4/0  13000       549        3
# 4     102501  0674023406000  00/06-34-067-02W4/0  13000       529        2
# 5     102503  0674030411000  00/11-04-067-03W4/0  13000     488.5        2
# 6     102505  0674030810000  00/10-08-067-03W4/0  13000     501.5        2
# 7     102507  0674031410000  00/10-14-067-03W4/0  13000     553.5        2
# 8     102514  0674032810000  00/10-28-067-03W4/0  13000     493.5        3
# 9     102517  0674033607000  00/07-36-067-03W4/0  13000     536.5        2
# 10    102518  0674040210000  00/10-02-067-04W4/0  13000       528        1
# ...

# %%
type(locations)
# Out:
# NoneType
